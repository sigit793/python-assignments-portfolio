# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# (a) 
x, y = sp.symbols('x y')
f = sp.exp(x) * sp.sin(y) + y**3
f_x = sp.diff(f, x)
f_y = sp.diff(f, y)
print (f_x)
print (f_y)

# (b) Compute gradient
g = x**2 * y + x * y**2
g_x = sp.diff(g, x)
g_y = sp.diff(g, y)
grad = sp.Matrix([g_x, g_y])
grad_magnitude = sp.sqrt(g_x.subs({x:1, y:-1})**2 + g_y.subs({x:1, y:-1})**2)
print (grad_magnitude)

# (c) Compute second partial derivatives 
h = sp.ln(x**2 + y**2)
h_xx = sp.diff(h, x, x)
h_yy = sp.diff(h, y, y)
h_xy = sp.diff(h, x, y)
h_yx = sp.diff(h, y, x)
print (h_xx)
print (h_yy)
print (h_xy)
print (h_yx)
print ("The mixed partials are the same indicating symmetry")

# (d) 
j = x**3 - 3*x*y + y**3
j_func = sp.lambdify((x, y), j, 'numpy')
x_vals = np.linspace(-3, 3, 400)
y_vals = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x_vals, y_vals)
Z = j_func(X, Y)
plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
plt.title('Contour plot of $j(x, y) = x^3 - 3xy + y^3$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# (e) 
m = x**5 + sp.cos(y)*sp.sin(x)
m_func = sp.lambdify((x, y), m, 'numpy')
Z2 = k_func(X, Y)
plt.contourf(X, Y, Z2, levels=50, cmap='plasma')
plt.colorbar()
plt.title('Contour plot of m(x, y) = x^5 + cos(y)sin(x)')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()
# Out:
# exp(x)*sin(y)
# 3*y**2 + exp(x)*cos(y)
# sqrt(2)
# 2*(-2*x**2/(x**2 + y**2) + 1)/(x**2 + y**2)
# 2*(-2*y**2/(x**2 + y**2) + 1)/(x**2 + y**2)
# -4*x*y/(x**2 + y**2)**2
# -4*x*y/(x**2 + y**2)**2
# The mixed partials are the same indicating symmetry
